# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import os
import glob
from time import time
import nltk , string , re
from textblob import TextBlob
from nltk.stem import PorterStemmer , WordNetLemmatizer
import gensim

# %%
df = pd.read_csv("./data/cars_description_dataset.csv")

df
# Out:
#       Unnamed: 0                   Full Name   car type  \
# 0              0          jeep wrangler 1998       jeep
# 1              1         toyota 4runner 2005     toyota
# 2              2          toyota tundra 2002     toyota
# 3              3          toyota tacoma 1998     toyota
# 4              4            ford ranger 1990       ford
# ...          ...                         ...        ...
# 3458        3458          jeep renegade 2023       jeep
# 3459        3459          bmw alpina-b7 2022        bmw
# 3460        3460     chevrolet colorado 2022  chevrolet
# 3461        3461           bmw 4-series 2023        bmw
# 3462        3462  ford f-250-super-duty 2022       ford
#
#                    car name  year  \
# 0             jeep wrangler  1998
# 1            toyota 4runner  2005
# 2             toyota tundra  2002
# 3             toyota tacoma  1998
# 4               ford ranger  1990
# ...                     ...   ...
# 3458          jeep renegade  2023
# 3459          bmw alpina-b7  2022
# 3460     chevrolet colorado  2022
# 3461           bmw 4-series  2023
# 3462  ford f-250-super-duty  2022
#
#                                                     url  \
# 0     https://www.edmunds.com/jeep/wrangler/1998/rev...
# 1     https://www.edmunds.com/toyota/4runner/2005/re...
# 2     https://www.edmunds.com/toyota/tundra/2002/rev...
# 3     https://www.edmunds.com/toyota/tacoma/1998/rev...
# 4      https://www.edmunds.com/ford/ranger/1990/review/
# ...                                                 ...
# 3458             https://www.edmunds.com/jeep/renegade/
# 3459             https://www.edmunds.com/bmw/alpina-b7/
# 3460        https://www.edmunds.com/chevrolet/colorado/
# 3461   https://www.edmunds.com/bmw/4-series/2023/m440i/
# 3462  https://www.edmunds.com/ford/f-250-super-duty/...
#
#                                                    Pros  \
# 0     ['Unmatched off-road capability, overflowing w...
# 1     ['Powerful engine lineup, well mannered on pav...
# 2     ['Silky V8, Toyota build quality, less-than-fu...
# 3     ['Unique styling, Toyota reliability, and powe...
# 4                                                 empty
# ...                                                 ...
# 3458  ["Trailhawk model's excellent off-road capabil...
# 3459  ['Smooth yet ridiculously quick acceleration',...
# 3460  ['Gasoline V6 and diesel four-cylinder engines...
# 3461  ['Powerful and fuel-efficient engines', "Sport...
# 3462  ['Diesel V8 generates immense power and torque...
#
#                                                    Cons  \
# 0     ['Soft top is fun, but still a pain in the $%!...
# 1     ["Cargo capacity isn't much more than what man...
# 2     ['Lacks wide range of choice offered by domest...
# 3     ['Extended cab models lack a third door and th...
# 4                                                 empty
# ...                                                 ...
# 3458  ['High price when optioned with nice-to-have f...
# 3459  ['Unintuitive gesture controls', "Rear seats d...
# 3460  ['Front seats can feel confining for larger pe...
# 3461  ['Flat hood makes it hard to place the front e...
# 3462  ['Price tag soars with options', 'Tall ride he...
#
#                                        Full Description  \
# 0     Jeep has improved off-road capability by incre...
# 1     The base V6 now comes with a five-speed automa...
# 2     SR5 models have new 16-inch wheels, and a limi...
# 3     The 1998 four-wheel-drive Tacomas receive fres...
# 4                       No changes for the Ford Ranger.
# ...                                                 ...
# 3458  The  2023 Jeep Renegade is a versatile subcomp...
# 3459  High-performance  M models have proliferated t...
# 3460  After  a handful of minor changes last year, t...
# 3461  The 4 Series is based on the 3  Series sedan b...
# 3462  If  Ford knows how to do anything, it's build ...
#
#                                     GPT-2 Summarization current price Min  \
# 0     Jeep has improved off-road capability by incre...           $2,423
# 1     The base V6 now comes with a five-speed automa...           $4,364
# 2     SR5 models have new 16-inch wheels, and a limi...           $3,324
# 3     The 1998 four-wheel-drive Tacomas receive fres...           $2,884
# 4                       No changes for the Ford Ranger.           $3,675
# ...                                                 ...               ...
# 3458  The  2023 Jeep Renegade is a versatile subcomp...               NaN
# 3459  High-performance  M models have proliferated t...               NaN
# 3460  After  a handful of minor changes last year, t...               NaN
# 3461  The 4 Series is based on the 3  Series sedan b...               NaN
# 3462  If  Ford knows how to do anything, it's build ...               NaN
#
#      current price Max
# 0               $4,074
# 1               $6,983
# 2               $5,612
# 3               $4,518
# 4               $5,757
# ...                ...
# 3458               NaN
# 3459               NaN
# 3460               NaN
# 3461               NaN
# 3462               NaN
#
# [3463 rows x 12 columns]
